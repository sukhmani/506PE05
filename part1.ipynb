# %%
from PIL import ImageFilter, Image
im = Image.open("PE05-input.jpg")
im1 = im.filter(ImageFilter.BLUR)
im2 = im.filter(ImageFilter.MinFilter(3))
im3 = im.filter(ImageFilter.MinFilter)

im1.show()
im2.show()
im3.show()
# Out:
# <PIL.Image.Image image mode=RGB size=581x374>
# <PIL.Image.Image image mode=RGB size=581x374>
# <PIL.Image.Image image mode=RGB size=581x374>

# %% [markdown]
# 2. CONTOUR

# %%
from PIL import Image, ImageFilter

# Load the image
im = Image.open("PE05-input.jpg")

# Apply the CONTOUR filter
im_contour = im.filter(ImageFilter.CONTOUR)

# Save and display the filtered image
im_contour.save("PE05_output_CONTOUR.jpg")
im_contour.show()
# Out:
# <PIL.Image.Image image mode=RGB size=581x374>

# %% [markdown]
# 3. DETAIL

# %%
from PIL import Image, ImageFilter

# Load the image
im = Image.open("PE05-input.jpg")

# Apply the DETAIL filter
im_detail = im.filter(ImageFilter.DETAIL)

# Save and display the filtered image
im_detail.save("PE05_output_DETAIL.jpg")
im_detail.show()
# Out:
# <PIL.Image.Image image mode=RGB size=581x374>

# %% [markdown]
# 4. EDGE_ENHANCE

# %%
from PIL import Image, ImageFilter

# Load the image
im = Image.open("PE05-input.jpg")

# Apply the EDGE_ENHANCE filter
im_edge_enhance = im.filter(ImageFilter.EDGE_ENHANCE)

# Save and display the filtered image
im_edge_enhance.save("PE05_output_EDGE_ENHANCE.jpg")
im_edge_enhance.show()
# Out:
# <PIL.Image.Image image mode=RGB size=581x374>

# %% [markdown]
# 5. EDGE_ENHANCE_MORE

# %%
from PIL import Image, ImageFilter

# Load the image
im = Image.open("PE05-input.jpg")

# Apply the EDGE_ENHANCE_MORE filter
im_edge_enhance_more = im.filter(ImageFilter.EDGE_ENHANCE_MORE)

# Save and display the filtered image
im_edge_enhance_more.save("PE05_output_EDGE_ENHANCE_MORE.jpg")
im_edge_enhance_more.show()
# Out:
# <PIL.Image.Image image mode=RGB size=581x374>

# %% [markdown]
# 6. EMBOSS

# %%
from PIL import Image, ImageFilter

# Load the image
im = Image.open("PE05-input.jpg")

# Apply the EMBOSS filter
im_emboss = im.filter(ImageFilter.EMBOSS)

# Save and display the filtered image
im_emboss.save("PE05_output_EMBOSS.jpg")
im_emboss.show()
# Out:
# <PIL.Image.Image image mode=RGB size=581x374>

# %% [markdown]
# 7. FIND_EDGES

# %%
from PIL import Image, ImageFilter

# Load the image
im = Image.open("PE05-input.jpg")

# Apply the FIND_EDGES filter
im_find_edges = im.filter(ImageFilter.FIND_EDGES)

# Save and display the filtered image
im_find_edges.save("PE05_output_FIND_EDGES.jpg")
im_find_edges.show()
# Out:
# <PIL.Image.Image image mode=RGB size=581x374>

# %% [markdown]
# 8. SHARPEN

# %%
from PIL import Image, ImageFilter

# Load the image
im = Image.open("PE05-input.jpg")

# Apply the SHARPEN filter
im_sharpen = im.filter(ImageFilter.SHARPEN)

# Save and display the filtered image
im_sharpen.save("PE05_output_SHARPEN.jpg")
im_sharpen.show()
# Out:
# <PIL.Image.Image image mode=RGB size=581x374>

# %% [markdown]
# 9. SMOOTH

# %%
from PIL import Image, ImageFilter

# Load the image
im = Image.open("PE05-input.jpg")

# Apply the SMOOTH filter
im_smooth = im.filter(ImageFilter.SMOOTH)

# Save and display the filtered image
im_smooth.save("PE05_output_SMOOTH.jpg")
im_smooth.show()
# Out:
# <PIL.Image.Image image mode=RGB size=581x374>

# %% [markdown]
# 10. SMOOTH_MORE

# %%
from PIL import Image, ImageFilter

# Load the image
im = Image.open("PE05-input.jpg")

# Apply the SMOOTH_MORE filter
im_smooth_more = im.filter(ImageFilter.SMOOTH_MORE)

# Save and display the filtered image
im_smooth_more.save("PE05_output_SMOOTH_MORE.jpg")
im_smooth_more.show()
# Out:
# <PIL.Image.Image image mode=RGB size=581x374>

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, ImageOps, ImageFilter, ImageEnhance
# %matplotlib inline

img = Image.open("PE05-input.jpg")
img = img.filter(ImageFilter.DETAIL)
img = img.filter(ImageFilter.SHARPEN)
img = img.filter(ImageFilter.MedianFilter())
img = img.filter(ImageFilter.UnsharpMask(5.0, 200, 20))
img = ImageEnhance.Sharpness(img).enhance(0.5)

plt.figure(figsize=(8, 8))
plt.imshow(np.array(img))
plt.axis('off')
plt.title("Enhanced Image")
plt.show()
