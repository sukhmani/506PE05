# %%
from PIL import Image, ImageOps, ImageFilter

# Open the input image
img = Image.open("PE05-input.jpg")
img.show()

# Apply histogram equalization
img_equalized = ImageOps.equalize(img)
img_equalized.save("PE05_output_equalized.jpg")
img_equalized.show()

# Unsharp Masking filter
img_unsharp = img_equalized.filter(ImageFilter.UnsharpMask(radius=2, percent=150, threshold=3))
img_unsharp.save("PE05_output_unsharp.jpg")
img_unsharp.show()  # Display the final enhanced image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=581x374>
# <PIL.Image.Image image mode=RGB size=581x374>
# <PIL.Image.Image image mode=RGB size=581x374>

# %% [markdown]
# Answer the following questions after you improved the image as an output image.
# 1. How many people do you see in the output image? 2
# 2. How many trees can you identify? 3
# 3. How many windows can you identify on the 2nd floor of the first building (labelled as “1”) on the
# right-hand side of the road? 3
# 4. How many windows can you identify in the second building (labeled as “2”) on the right-hand
# side of the road facing you? 8
